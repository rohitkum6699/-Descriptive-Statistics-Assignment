# %% [markdown]
# #Q1)  Understanding Central Tendency
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
# #Ans-->
# ### --> The Data
# Sales (in dozens of muffins) over 7 days:
# \[
# [10, 12, 11, 15, 14, 13, 12]
# \]
#
# ### --> Measures of Central Tendency
# - **Mean (Average):**
# \[
# \frac{10 + 12 + 11 + 15 + 14 + 13 + 12}{7} = \frac{87}{7} \approx 12.43
# \]
# So, the average is about **12.4 dozens**.
#
# - **Median (Middle Value):**
# Ordered data: \([10, 11, 12, 12, 13, 14, 15]\)
# The middle value is **12**.
#
# - **Mode (Most Frequent Value):**
# The value **12** appears twice, more than any other.
# So, the mode is **12**.
#
# ### --> Most Representative Value
# The **mean (≈12.4)** is slightly higher than the median and mode (both 12). Since the data is fairly balanced (no extreme outliers), the **mean** is the most representative value of weekly sales.
#
# -->In practical terms, the bakery sells about **12 dozens muffins per day on average**, which best summarizes their weekly performance.

# %% [markdown]
# #Q2) Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
# #Ans-->
# ### --> The Data
# Quiz scores:
# \[
# [12, 15, 14, 16, 18, 20, 19]
# \]
#
# ### -->Step 1: Calculate the Mean
# \[
# \text{Mean} = \frac{12 + 15 + 14 + 16 + 18 + 20 + 19}{7}
# \]
# \[
# = \frac{114}{7} \approx 16.3
# \]
#
# So, the **mean score is about 16.3**.
#
# ### --> Step 2: Interpret the Mean
# - The mean represents the **average performance** of the class.
# - Since the quiz scores range from 12 to 20, the mean of 16.3 shows that most students scored **above the midpoint** of the range.
# - This suggests the class performed **quite well overall**, with the average student achieving a strong score.
#
# -->In real life, the teacher can use this mean to quickly summarize the class’s performance: *“On average, students scored about 16 marks, which indicates good understanding of the material.”*

# %% [markdown]
# #Q3) Mode in Real Life (Easy)
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
# #Ans-->
#  # The Data
# Shoe sizes sold:
# \[
# [7, 8, 9, 8, 8, 10, 7, 9]
# \]
#
# ### 🧮 Step 1: Find the Mode
# - Count each size:
#   - Size 7 → 2 times
#   - Size 8 → 3 times
#   - Size 9 → 2 times
#   - Size 10 → 1 time
#
# --> The **mode is 8**, since it occurs most frequently.
#
# ### --> Step 2: Why This Is Useful
# - The mode tells the manager which shoe size is **most in demand**.
# - Knowing that size 8 sells the most helps with **inventory planning**: the manager can stock more of size 8 to avoid running out.
# - It also guides **future purchasing decisions**, promotions, and even marketing strategies (e.g., highlighting availability of popular sizes).
#
# --> In real life, the mode is a practical tool for businesses to understand customer preferences and optimize supply.

# %% [markdown]
# #Q4) Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median
# #Ans--> Great scenario—this is exactly where the **median** shines!
#
# ### --> The Data
# Car prices:
# \[
# [8{,}000,\; 9{,}500,\; 10{,}200,\; 11{,}000,\; 50{,}000]
# \]
#
# ### --> Step 1: Calculate the Median
# - First, order the data (already ordered).
# - Since there are **5 values**, the median is the **middle one** (3rd value).
# \[
# \text{Median} = 10{,}200
# \]
#
# ### --> Step 2: Why Median Is Better Here
# - The **mean** would be:
# \[
# \frac{8{,}000 + 9{,}500 + 10{,}200 + 11{,}000 + 50{,}000}{5} = \frac{88{,}700}{5} = 17{,}740
# \]
# - Notice how the **$50,000 car** (an outlier) pulls the mean way up to $17,740, which doesn’t reflect the typical prices most customers see.
# - The **median ($10,200)**, however, represents the central tendency without being distorted by extreme values.
#
# ### -->Conclusion
# The **median ($10,200)** is a better measure of central tendency in this case because it gives a more realistic picture of the “typical” used car price, while the mean is skewed by the unusually high-priced car.

# %% [markdown]
# #Q5)  Dispersion Introduction (Medium)
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time
# #Ans--> Great example to introduce **dispersion**! Let’s work it out step by step
#
# ### --> The Data
# Puzzle completion times (in minutes):
# \[
# [25, 30, 27, 35, 40]
# \]
#
# ### --> Step 1: Calculate the Range
# \[
# \text{Range} = \text{Maximum} - \text{Minimum} = 40 - 25 = 15
# \]
#
# So, the **range is 15 minutes**.
#
# ### --> Step 2: What the Range Tells Us
# - The range shows the **spread** of the data — how much the times vary from the fastest to the slowest day.
# - A range of 15 minutes means the student’s puzzle-solving time can differ by as much as **15 minutes** depending on the day.
# - This indicates **moderate variation**: the student is not perfectly consistent, but also not wildly unpredictable.
#
# ### --> Conclusion
# The **range (15 minutes)** tells us that while the student sometimes solves puzzles quickly (25 minutes), other times it takes much longer (up to 40 minutes). It highlights the **extent of variation** in performance, which is the first step in understanding consistency.

# %% [markdown]
# #Q6) Range in Action (Medium)
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging
# #Ans--> The Data
# Weekly apple harvest weights (kg):
# \[
# [100, 105, 98, 110, 120]
# \]
#
# ### --> Step 1: Calculate the Range
# \[
# \text{Range} = \text{Maximum} - \text{Minimum} = 120 - 98 = 22
# \]
# So, the **range is 22 kg**.
#
# ### --> Step 2: What the Range Tells Us
# - The range shows the **variation** in weekly harvest weights.
# - A difference of **22 kg** means the farmer’s harvest fluctuates noticeably from week to week.
# - This helps the farmer understand that packaging needs must be **flexible**:
#   - On lighter weeks (around 98 kg), fewer boxes or smaller packaging may be enough.
#   - On heavier weeks (up to 120 kg), extra boxes or larger packaging will be required.
#
# ### --> Conclusion
# The **range (22 kg)** helps the farmer anticipate the **maximum and minimum packaging needs**. By planning for this variation, the farmer avoids shortages of boxes on heavy weeks and prevents waste of unused packaging on lighter weeks.

# %% [markdown]
# #Q7) Variance for Decision-Making (Medium)
# Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
# Which company is more consistent, and why?
# #Ans-->  Understanding the Data
# - **Company A:** Variance = 6
# - **Company B:** Variance = 15
#
# ### -->Step 1: What Variance Means
# - Variance measures how **spread out** the data is around the mean.
# - A **smaller variance** means the values are closer to the average → more consistency.
# - A **larger variance** means the values fluctuate more → less consistency.
#
# ###--> Step 2: Compare the Companies
# - Company A’s variance (6) is **lower** than Company B’s (15).
# - This means Company A’s delivery delays are **more tightly clustered** around the average delay.
# - Company B’s higher variance shows **greater unpredictability** in delivery times.
#
# ### --> Conclusion
# **Company A is more consistent** because its variance is smaller. This indicates customers can expect delivery times that are more reliable and closer to the average, while Company B’s delays vary more widely.

# %% [markdown]
# #Q8)  Standard Deviation in Context (Hard)
# A finance student compares the daily price fluctuations of two cryptocurrencies.
# Coin A: standard deviation = $30
# Coin B: standard deviation = $120
# Which coin is riskier to invest in, and why?
# #Ans--> The Data
# - **Coin A:** Standard deviation = \$30
# - **Coin B:** Standard deviation = \$120
#
# ### --> Step 1: What Standard Deviation Means
# - Standard deviation measures how much values **deviate from the average**.
# - A **small standard deviation** → prices stay close to the mean → more stability.
# - A **large standard deviation** → prices swing widely → more volatility.
#
# ### --> Step 2: Compare the Coins
# - Coin A’s fluctuations are relatively small (\$30 around the average).
# - Coin B’s fluctuations are much larger (\$120 around the average).
# - This means Coin B’s price is **less predictable** and can change drastically day to day.
#
# ### -->Conclusion
# **Coin B is riskier to invest in** because its **higher standard deviation (\$120)** indicates greater volatility. Investors face more uncertainty and potential for large gains or losses compared to Coin A, which is more stable.

# %% [markdown]
# #Q9) Combining Measures (Hard)
#
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410]
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
# #Ans-->
# ### The Data
# Monthly usage (kWh):
# \[
# [400, 420, 390, 450, 410]
# \]
#
# ---
#
# ### --> Step 1: Mean (Average)
# \[
# \text{Mean} = \frac{400 + 420 + 390 + 450 + 410}{5} = \frac{2070}{5} = 414
# \]
# So, the **mean usage is 414 kWh per month**.
#
# ---
#
# ### -->Step 2: Standard Deviation
# 1. Find deviations from the mean:
#    - \(400 - 414 = -14\)
#    - \(420 - 414 = 6\)
#    - \(390 - 414 = -24\)
#    - \(450 - 414 = 36\)
#    - \(410 - 414 = -4\)
#
# 2. Square deviations:
#    - \((-14)^2 = 196\)
#    - \(6^2 = 36\)
#    - \((-24)^2 = 576\)
#    - \(36^2 = 1296\)
#    - \((-4)^2 = 16\)
#
# 3. Mean of squared deviations (variance):
# \[
# \frac{196 + 36 + 576 + 1296 + 16}{5} = \frac{2120}{5} = 424
# \]
#
# 4. Standard deviation:
# \[
# \sqrt{424} \approx 20.6
# \]
#
# So, the **standard deviation is about 21 kWh**.
#
# ---
#
# ### -->Step 3: Interpretation
# - **Mean (414 kWh):** The family typically uses about 414 kWh per month.
# - **Standard deviation (≈21 kWh):** Their usage varies only slightly (±21 kWh) from the average.
#
# ### --> Conclusion
# Together, these measures show that the family’s electricity usage is **stable and consistent**. They consume around **414 kWh each month**, with only small fluctuations. This pattern suggests predictable energy needs, which is useful for **budgeting** and **planning efficient energy use**.

# %% [markdown]
# #Q10) : Practical Application (Hard)
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance
# #Ans-->
#
# ###  The Data
# Points in 8 games:
# \[
# [15, 18, 20, 22, 25, 17, 19, 21]
# \]
#
# ---
#
# ###--> Step 1: Mean (Average)
# \[
# \text{Mean} = \frac{15 + 18 + 20 + 22 + 25 + 17 + 19 + 21}{8} = \frac{157}{8} = 19.6
# \]
#  The player averages **19.6 points per game**.
#
# ---
#
# ### --> Step 2: Median (Middle Value)
# Ordered data: \([15, 17, 18, 19, 20, 21, 22, 25]\)
# With 8 values, the median is the average of the 4th and 5th:
# \[
# \frac{19 + 20}{2} = 19.5
# \]
# --> The **median is 19.5 points**.
#
# ---
#
# ### --> Step 3: Mode (Most Frequent Value)
# Each score occurs only once.
#  **No mode** (all values are unique).
#
# ---
#
# ### -->Step 4: Range (Spread)
# \[
# \text{Range} = 25 - 15 = 10
# \]
# The scores vary within a **10-point window**.
#
# ---
#
# ###--> Step 5: Standard Deviation
# 1. Mean = 19.6
# 2. Deviations:
#    - \(15 - 19.6 = -4.6\)
#    - \(18 - 19.6 = -1.6\)
#    - \(20 - 19.6 = 0.4\)
#    - \(22 - 19.6 = 2.4\)
#    - \(25 - 19.6 = 5.4\)
#    - \(17 - 19.6 = -2.6\)
#    - \(19 - 19.6 = -0.6\)
#    - \(21 - 19.6 = 1.4\)
#
# 3. Squared deviations:
#    - 21.16, 2.56, 0.16, 5.76, 29.16, 6.76, 0.36, 1.96
#    Sum = 67.88
#
# 4. Variance:
# \[
# \frac{67.88}{8} = 8.49
# \]
#
# 5. Standard deviation:
# \[
# \sqrt{8.49} \approx 2.9
# \]
#  The **standard deviation is about 2.9 points**.
#
# ---
#
# ### Insights
# - **Mean (19.6)**: The player consistently scores around 20 points per game.
# - **Median (19.5)**: The middle score aligns closely with the mean → balanced performance.
# - **No Mode**: No single score dominates → variety in performance.
# - **Range (10)**: Scores fluctuate between 15 and 25 points, showing some variability.
# - **Standard Deviation (≈2.9)**: Most scores are within ±3 points of the average → **steady and reliable scoring**.
#
# ### --> Conclusion
# The player is a **consistent performer**, typically scoring around 20 points per game with only moderate variation. This reliability makes them a dependable contributor to the team’s offense.
